# %% [markdown]
# # 앤스콤 데이터 집합 불러오기

# %%
#1
import seaborn as sns

anscombe = sns.load_dataset("anscombe")
print(anscombe.head())
print(type(anscombe))
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # matplotlib 라이브러리로 간단한 그래프 그리기

# %%
#2
# %matplotlib notebook
import matplotlib .pyplot as plt

# %%
#3
dataset_1 = anscombe[anscombe['dataset'] == 'I']

# %%
#4
plt.plot(dataset_1['x'], dataset_1['y'])
# Out:
# <img src="data:image/png;base64,..." width="420.6666666666667">

# %%
#5
plt.plot(dataset_1['x'], dataset_1['y'],'o')

# %% [markdown]
# # 한 번에 4개의 그래프 그리기

# %%
#1
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
#2
fig = plt.figure()

#3
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)
# Out:
# <img src="data:image/png;base64,..." width="418">

# %%
#4
axes1.plot(dataset_1['x'], dataset_1['y'], 'o') 
axes2.plot(dataset_2['x'], dataset_2['y'], 'o') 
axes3.plot(dataset_3['x'], dataset_3['y'], 'o') 
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

fig
# Out:
# <img src="data:image/png;base64,..." width="418">

# %%
#5
axes1.set_title("dataset_1")
axes2.set_title("dataset_2")
axes3.set_title("dataset_3")
axes4.set_title("dataset_4")

fig
# Out:
# <img src="data:image/png;base64,..." width="418">

# %%
#6
fig.suptitle("Anscombe Data")

fig
# Out:
# <img src="data:image/png;base64,..." width="418">

# %%
#7
fig.tight_layout()

fig
# Out:
# <img src="data:image/png;base64,..." width="418">

# %% [markdown]
# # 기초 그래프 그리기 - 히스토그램, 산점도, 박스 그래프

# %%
#1
tips = sns.load_dataset("tips")
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %% [raw]
# #2 히스토그램(일변량 그래프)
# : 데이터프레임의 열 데이터 분포와 빈도를 살펴보는 용도

# %%
#3
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
# Out:
# <img src="data:image/png;base64,..." width="444.6666666666667">

# %%
#4
axes1.hist(tips['total_bill'],bins= 10)
axes1.set_title('Hisogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')

fig
# Out:
# <img src="data:image/png;base64,..." width="444.6666666666667">

# %% [raw]
# #5 산점도 그래프(이변량 그래프)
# 변수 2개를 사용해서 만든 그래프

# %%
#6
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)
axes1.scatter(tips['total_bill'], tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="504.6666666666667">
# Text(0, 0.5, 'Tip')

# %%
#7 박스그래프
: 이산형 변수와 연속형 변수를 함께 사용하는 그래프
이산형 변수: 명확하게 구분되는 값 
연속형 변수: 명확하게 셀 수 없는 범위의 값

# %%
#8
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1, 1, 1)

axes1.boxplot([tips[tips['sex'] == 'Female']['tip'],
              tips[tips['sex'] == 'Male']['tip']],
              labels = ['Female', 'Male'])

axes1.set_xlabel('sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tip by Sex')
# Out:
# <img src="data:image/png;base64,..." width="382">
# Text(0.5, 1.0, 'Boxplot of Tip by Sex')

# %% [markdown]
# # 다변향 그래프로 다변향 그리기 - 산점도 그래프

# %% [raw]
# 다변형 그래프
# : 3개 이상의 변수를 사용한 그래프

# %%
#1
def record_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1

# %%
#2
tips['sex_color'] = tips['sex'].apply(record_sex)

# %%
#3
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)
axes1.scatter(
    x = tips['total_bill'],
    y = tips['tip'],
    s = tips['size'] * 10,
    c = tips['sex_color'],
    alpha = 0.5)
axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="454">
# Text(0, 0.5, 'Tip')

# %% [markdown]
# # 단변량 그래프 그리기 - 히스토그램

# %%
#1

import seaborn as sns

tips = sns.load_dataset("tips")

# %%
#2
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Historgram with Desity Plot')
# Out:
# <img src="data:image/png;base64,..." width="492">
# Text(0.5, 1.0, 'Total Bill Historgram with Desity Plot')

# %%
#3
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], kde=False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# <img src="data:image/png;base64,..." width="548">
# Text(0, 0.5, 'Frequency')

# %%
#4
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], hist=False)
ax.set_title('Total Bill Density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit Probability')
# Out:
# <img src="data:image/png;base64,..." width="505.3333333333333">
# Text(0, 0.5, 'Unit Probability')

# %%
#5
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], rug=True)
ax.set_title('Total Bill Histogram with Desity and Rug Plot')
ax.set_xlabel('Total Bill')
# Out:
# <img src="data:image/png;base64,..." width="488">
# Text(0.5, 0, 'Total Bill')

# %%
#6
ax = plt.subplots()
ax = sns.countplot('day', data=tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# <img src="data:image/png;base64,..." width="358.6666666666667">
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # 다양한 종류의 이변량 그래프 그리기

# %% [markdown]
# ### seaborn 라이브러리로 산점도 그래프 그리기

# %%
#1
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False )
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="364">
# Text(0, 0.5, 'Tip')

# %%
#2
joint = sns.jointplot(x='total_bill', y='tip', data=tips)
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill amd Tip', fontsize=10, y=1.03)
# Out:
# <img src="data:image/png;base64,..." width="458">
# Text(0.5, 1.03, 'Joint Plot of Total Bill amd Tip')

# %%
#3
hexbin = sns.jointplot(x="total_bill", y="tip", data=tips, kind='hex')
hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# <img src="data:image/png;base64,..." width="440">
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %%
#4
ax = plt.subplots()
ax = sns.kdeplot(data=tips['total_bill'],
                data2=tips['tip'],
                shade=True)
ax.set_title('Kernel Density Plot df Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="446.6666666666667">
# Text(0, 0.5, 'Tip')

# %%
#5
ax = plt.subplots()
ax = sns.barplot(x='time', y='total_bill', data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time od day')
ax.set_ylabel('Average total bill')
# Out:
# <img src="data:image/png;base64,..." width="510">
# Text(0, 0.5, 'Average total bill')

# %%
#6
ax = plt.subplots()
ax = sns.boxplot(x='time', y='total_bill', data=tips)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# <img src="data:image/png;base64,..." width="434">
# Text(0, 0.5, 'Total Bill')

# %%
#7
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', data=tips)
ax.set_title('Violin of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total bill')
# Out:
# <img src="data:image/png;base64,..." width="486">
# Text(0, 0.5, 'Total bill')

# %%
#8
fig = sns.pairplot(tips)
# Out:
# <img src="data:image/png;base64,..." width="508">

# %%
#9
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot) 
pair_grid = pair_grid.map_lower(sns.kdeplot) 
pair_grid = pair_grid.map_diag(sns.distplot, rug=True) 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="534">

# %% [markdown]
# # 다변량 그래프 그리기

# %%
#1
ax = plt.subplot()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
#2-1
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex',fit_reg=False)
# Out:
# <img src="data:image/png;base64,..." width="460">

# %%
#2-2
fig = sns.pairplot(tips, hue='sex')
# Out:
# <img src="data:image/png;base64,..." width="502.6666666666667">

# %%
#3
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', scatter_kws={'s': tips['size']*10})
# Out:
# <img src="data:image/png;base64,..." width="468">

# %% [markdown]
# # 데이터프레임과 시리즈로 그래프 그리기

# %%
#4
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', markers=['o', 'x'], scatter_kws={'s': tips['size']*10})
# Out:
# <img src="data:image/png;base64,..." width="488.6666666666667">

# %%
#5
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False)
# Out:
# <img src="data:image/png;base64,..." width="342">

# %%
#6
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False, col='dataset', col_wrap=2)
# Out:
# <img src="data:image/png;base64,..." width="458.6666666666667">

# %% [markdown]
# # 알아두면 좋아요

# %%
#1
facet = sns.FacetGrid(tips, col='time') 
facet.map(sns.distplot, 'total_bill', rug=True)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
#2
facet = sns.FacetGrid(tips, col='day', hue='sex') 
facet = facet.map(plt.scatter, 'total_bill', 'tip') 
facet = facet.add_legend()
# Out:
# <img src="data:image/png;base64,..." width="740.6666666666666">

# %%
#3
facet = sns.FacetGrid(tips, col='time', row='smoker', hue='sex') 
facet.map(plt.scatter, 'total_bill', 'tip')
# Out:
# <img src="data:image/png;base64,..." width="462.6666666666667">

# %% [markdown]
# # 데이터프레임과 시리즈로 그래프 그리기

# %%
#1
fig, ax = plt.subplots()
ax = tips['total_bill'].plot.hist()
# Out:
# <img src="data:image/png;base64,..." width="446">

# %%
#2
fig, ax = plt.subplots() 
ax = tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=ax)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="336.6666666666667">

# %%
#3-1
fig, ax = plt.subplots() 
ax = tips['tip'].plot.kde()
# Out:
# <img src="data:image/png;base64,..." width="436">

# %%
#3-2
fig, ax = plt.subplots() 
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="372.6666666666667">

# %%
#3-3
fig, ax = plt.subplots() 
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="412.6666666666667">

# %%
#4
fig, ax = plt.subplots() 
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="398.6666666666667">

# %%
#5
fig, ax = plt.subplots() 
ax = tips.plot.box(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="462.6666666666667">

# %% [markdown]
# # 그래프에 스타일 적용하기

# %%
#1
fig, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)
# Out:
# <img src="data:image/png;base64,..." width="412">
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#2
sns.set_style('whitegrid') 
fig, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)
# Out:
# <img src="data:image/png;base64,..." width="444.6666666666667">

# %%
#3
fig = plt.figure() 
seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks'] 
for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(x='time', y='total_bill', data=tips, ax=ax)
        violin.set_title(style) 
        
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="494">
