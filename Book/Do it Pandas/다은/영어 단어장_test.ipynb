# %%
import os
import io
import random
import numpy as np
import pandas as pd


col = pd.read_csv("C:/Users/tb990/Documents/word/콜로케이션.csv", engine='python', encoding='UTF-8').fillna('없음')
# print(col.head())
col
# Out:
#                   word       mean1 mean2
# 0    arrange a meeting    회의를 준비하다    없음
# 1   flight arrangement      비행편 마련    없음
# 2               adjust        조정하다  적응하다
# 3          load a cart   카트에 짐을 싣다    없음
# 4               unload      짐을 내리다    없음
# 5             occupied        사용중인    없음
# 6               occupy        사용하다  거주하다
# 7            bend over  ~위로 몸을 굽히다    없음
# 8         lean against         기대다    없음
# 9           throw away         버리다    없음
# 10          aisle seat         통로석    없음
# 11      be filled with    ~으로 가득하다    없음
# 12          inspection          점검    없음
# 13           inspecter         검사관    없음
# 14                trim         다듬다  손질하다
# 15            pavement          인도  포장도로

# %%
col['random']=np.random.choice(col['word'], size=len(col['word']), replace=False)

for j in range(1,len(col['word'])):
        i=0
        j=1
        while (i < len(col['word'])):  
                print("  {}번".format(j)) 
                que = col['random'][i]
                print("    ", que)
                ans = input("     ")
                confirm1 = col[col['mean1'].str.contains(ans)]
                compare1 = confirm1['mean1'].tolist()
                confirm2 = col[col['mean2'].str.contains(ans)]
                compare2 = confirm2['mean2'].tolist()
                print("---------------------------------------------------------------------------------------------------")
                
                if ans in compare1 or ans in compare2:
                     print("     정답!")
                else:
#                     diction = col.set_index('word').T.to_dict('list')
#                     print(diction[])
#                     if que in list(diction.keys()):
#                         prin
                    
                    print("     오답!^^ 정답은 {}".format(correct))
#                     print(que ==  )
                    
                print("===================================================================================================")
                j += 1
                i += 1
                
        break
# Out:
#   1번
#      occupy
#
# ---------------------------------------------------------------------------------------------------
#      오답!^^ 정답은 occupy
# ===================================================================================================
#   2번
#      trim
#
# ---------------------------------------------------------------------------------------------------
#      오답!^^ 정답은 trim
# ===================================================================================================
#   3번
#      throw away
#
# ---------------------------------------------------------------------------------------------------
#      오답!^^ 정답은 throw away
# ===================================================================================================
#   4번
#      occupied
#
# ---------------------------------------------------------------------------------------------------
#      오답!^^ 정답은 occupied
# ===================================================================================================
#   5번
#      flight arrangement
#
# ---------------------------------------------------------------------------------------------------
#      오답!^^ 정답은 flight arrangement
# ===================================================================================================
#   6번
#      adjust
#
# ---------------------------------------------------------------------------------------------------
#      오답!^^ 정답은 adjust
# ===================================================================================================
#   7번
#      load a cart
#
# ---------------------------------------------------------------------------------------------------
#      오답!^^ 정답은 load a cart
# ===================================================================================================
#   8번
#      be filled with
#
# ---------------------------------------------------------------------------------------------------
#      오답!^^ 정답은 be filled with
# ===================================================================================================
#   9번
#      pavement
#
# ---------------------------------------------------------------------------------------------------
#      오답!^^ 정답은 pavement
# ===================================================================================================
#   10번
#      lean against
#
# ---------------------------------------------------------------------------------------------------
#      오답!^^ 정답은 lean against
# ===================================================================================================
#   11번
#      aisle seat
#
# ---------------------------------------------------------------------------------------------------
#      오답!^^ 정답은 aisle seat
# ===================================================================================================
#   12번
#      inspecter
#
# ---------------------------------------------------------------------------------------------------
#      오답!^^ 정답은 inspecter
# ===================================================================================================
#   13번
#      arrange a meeting
#
# ---------------------------------------------------------------------------------------------------
#      오답!^^ 정답은 arrange a meeting
# ===================================================================================================
#   14번
#      inspection
#
# ---------------------------------------------------------------------------------------------------
#      오답!^^ 정답은 inspection
# ===================================================================================================
#   15번
#      unload
#
# ---------------------------------------------------------------------------------------------------
#      오답!^^ 정답은 unload
# ===================================================================================================
#   16번
#      bend over
#
# ---------------------------------------------------------------------------------------------------
#      오답!^^ 정답은 bend over
# ===================================================================================================
